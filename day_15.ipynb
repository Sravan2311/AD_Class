# %% [markdown]
# <a href="https://colab.research.google.com/github/Sravan2311/AD_Class/blob/main/day_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.stats import zscore
import seaborn as sns
import numpy as np
data=sns.load_dataset('iris')
df=data.copy()
z_scores=np.abs(zscore(df.drop('species',axis=1)))
z_scores
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0        0.900681     1.019004      1.340227     1.315444
# 1        1.143017     0.131979      1.340227     1.315444
# 2        1.385353     0.328414      1.397064     1.315444
# 3        1.506521     0.098217      1.283389     1.315444
# 4        1.021849     1.249201      1.340227     1.315444
# ..            ...          ...           ...          ...
# 145      1.038005     0.131979      0.819596     1.448832
# 146      0.553333     1.282963      0.705921     0.922303
# 147      0.795669     0.131979      0.819596     1.053935
# 148      0.432165     0.788808      0.933271     1.448832
# 149      0.068662     0.131979      0.762758     0.790671
#
# [150 rows x 4 columns]

# %%
zscore(df.drop('species',axis=1))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0       -0.900681     1.019004     -1.340227    -1.315444
# 1       -1.143017    -0.131979     -1.340227    -1.315444
# 2       -1.385353     0.328414     -1.397064    -1.315444
# 3       -1.506521     0.098217     -1.283389    -1.315444
# 4       -1.021849     1.249201     -1.340227    -1.315444
# ..            ...          ...           ...          ...
# 145      1.038005    -0.131979      0.819596     1.448832
# 146      0.553333    -1.282963      0.705921     0.922303
# 147      0.795669    -0.131979      0.819596     1.053935
# 148      0.432165     0.788808      0.933271     1.448832
# 149      0.068662    -0.131979      0.762758     0.790671
#
# [150 rows x 4 columns]

# %%
z_scores
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0        0.900681     1.019004      1.340227     1.315444
# 1        1.143017     0.131979      1.340227     1.315444
# 2        1.385353     0.328414      1.397064     1.315444
# 3        1.506521     0.098217      1.283389     1.315444
# 4        1.021849     1.249201      1.340227     1.315444
# ..            ...          ...           ...          ...
# 145      1.038005     0.131979      0.819596     1.448832
# 146      0.553333     1.282963      0.705921     0.922303
# 147      0.795669     0.131979      0.819596     1.053935
# 148      0.432165     0.788808      0.933271     1.448832
# 149      0.068662     0.131979      0.762758     0.790671
#
# [150 rows x 4 columns]

# %%
thresold=3
non=(z_scores<thresold).all(axis=1)
df_no=df[non]

# %%
df_no
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [149 rows x 5 columns]

# %%
thresold=3
no=(z_scores>thresold)
df_rows=df[no.any(axis=1)]

# %%
df_rows
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 15           5.7          4.4           1.5          0.4  setosa

# %%
from sklearn.ensemble import IsolationForest
import seaborn as sns
import numpy as np
import pandas as pd
data=sns.load_dataset('iris')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['species']=le.fit_transform(data['species'])

# %%
clf=IsolationForest(random_state=10,contamination=.01)
clf.fit(data)
# Out:
# IsolationForest(contamination=0.01, random_state=10)

# %%
y=clf.predict(data)
idx=np.where(y==-1)
idx[0]
# Out:
# array([117, 131])
